# %%
# Syeda A. Khalid
# Popularity Prediction (Binary Classification)

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# ======================
# LOAD DATA
# ======================
X_train = pd.read_csv("X_train.csv")
X_val = pd.read_csv("X_val.csv")
X_test = pd.read_csv("X_test.csv")

y_train = pd.read_csv("y_popular_class_train.csv")
y_val = pd.read_csv("y_popular_class_val.csv")
y_test = pd.read_csv("y_popular_class_test.csv")

# ======================
# FIX TARGET COLUMN (IMPORTANT)
# ======================
y_train = y_train.iloc[:, -1]
y_val = y_val.iloc[:, -1]
y_test = y_test.iloc[:, -1]

# ======================
# CHECK SHAPES (DEBUG)
# ======================
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

# ======================
# MODEL
# ======================
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# ======================
# PREDICT
# ======================
y_pred = model.predict(X_test)

# ======================
# RESULTS
# ======================
print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# X_train: (58435, 15)
# y_train: (58435,)
#
# Accuracy: 0.7652132247244849
#
# Confusion Matrix:
#  [[6286 1981]
#  [1939 6490]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      8267
#            1       0.77      0.77      0.77      8429
#
#     accuracy                           0.77     16696
#    macro avg       0.77      0.77      0.77     16696
# weighted avg       0.77      0.77      0.77     16696
